# %% [markdown]
# # Reconhecimento Facial utilizando um modelo pré-treinado
#
#
# A implementação é inspirada em dois artigos inovadores sobre reconhecimento facial usando redes neurais convolucionais, nomeadas de FaceNet e DeepFace.
#
# Foi utilizado o modelo pré-treinado Keras-OpenFace , que é uma implementação open source do OpenFace no Keras (Implementado originalmente no PyTorch)
#
# O modelo pré-treinado utilizado foi a implementação do Victor Sy Wang's, e foi carregado com o seguinte código:
# https://github.com/iwantooxxoox/Keras-OpenFace.

# %% [markdown]
# # Importação das bibliotecas
#
# Importar o arquivo utils.py do https://github.com/iwantooxxoox/Keras-OpenFace/blob/master/utils.py no qual contém funções utéis para a criação da rede neural e carregar seus pesos.

# %%
from keras.models import Sequential
from keras.layers import Conv2D, ZeroPadding2D, Activation, Input, concatenate
from keras.models import Model
from keras.layers.normalization import BatchNormalization
from keras.layers.pooling import MaxPooling2D, AveragePooling2D
from keras.layers.merge import Concatenate
from keras.layers.core import Lambda, Flatten, Dense
from keras.engine.topology import Layer
from keras import backend as K
import cv2
import os
import numpy as np
from numpy import genfromtxt
import pandas as pd
import tensorflow as tf
from utils import LRN2D
import utils

# %load_ext autoreload
# %autoreload 2

#np.set_printoptions(threshold=np.nan)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Construção da Rede Neural
#
# O modelo implementado é baseado no modelo FaceNet.
#
# A implementação do modelo está disponível aqui: https://github.com/iwantooxxoox/Keras-OpenFace

# %%
myInput = Input(shape=(96, 96, 3))

x = ZeroPadding2D(padding=(3, 3), input_shape=(96, 96, 3))(myInput)
x = Conv2D(64, (7, 7), strides=(2, 2), name='conv1')(x)
x = BatchNormalization(axis=3, epsilon=0.00001, name='bn1')(x)
x = Activation('relu')(x)
x = ZeroPadding2D(padding=(1, 1))(x)
x = MaxPooling2D(pool_size=3, strides=2)(x)
x = Lambda(LRN2D, name='lrn_1')(x)
x = Conv2D(64, (1, 1), name='conv2')(x)
x = BatchNormalization(axis=3, epsilon=0.00001, name='bn2')(x)
x = Activation('relu')(x)
x = ZeroPadding2D(padding=(1, 1))(x)
x = Conv2D(192, (3, 3), name='conv3')(x)
x = BatchNormalization(axis=3, epsilon=0.00001, name='bn3')(x)
x = Activation('relu')(x)
x = Lambda(LRN2D, name='lrn_2')(x)
x = ZeroPadding2D(padding=(1, 1))(x)
x = MaxPooling2D(pool_size=3, strides=2)(x)

# Inception3a
inception_3a_3x3 = Conv2D(96, (1, 1), name='inception_3a_3x3_conv1')(x)
inception_3a_3x3 = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3a_3x3_bn1')(inception_3a_3x3)
inception_3a_3x3 = Activation('relu')(inception_3a_3x3)
inception_3a_3x3 = ZeroPadding2D(padding=(1, 1))(inception_3a_3x3)
inception_3a_3x3 = Conv2D(128, (3, 3), name='inception_3a_3x3_conv2')(inception_3a_3x3)
inception_3a_3x3 = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3a_3x3_bn2')(inception_3a_3x3)
inception_3a_3x3 = Activation('relu')(inception_3a_3x3)

inception_3a_5x5 = Conv2D(16, (1, 1), name='inception_3a_5x5_conv1')(x)
inception_3a_5x5 = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3a_5x5_bn1')(inception_3a_5x5)
inception_3a_5x5 = Activation('relu')(inception_3a_5x5)
inception_3a_5x5 = ZeroPadding2D(padding=(2, 2))(inception_3a_5x5)
inception_3a_5x5 = Conv2D(32, (5, 5), name='inception_3a_5x5_conv2')(inception_3a_5x5)
inception_3a_5x5 = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3a_5x5_bn2')(inception_3a_5x5)
inception_3a_5x5 = Activation('relu')(inception_3a_5x5)

inception_3a_pool = MaxPooling2D(pool_size=3, strides=2)(x)
inception_3a_pool = Conv2D(32, (1, 1), name='inception_3a_pool_conv')(inception_3a_pool)
inception_3a_pool = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3a_pool_bn')(inception_3a_pool)
inception_3a_pool = Activation('relu')(inception_3a_pool)
inception_3a_pool = ZeroPadding2D(padding=((3, 4), (3, 4)))(inception_3a_pool)

inception_3a_1x1 = Conv2D(64, (1, 1), name='inception_3a_1x1_conv')(x)
inception_3a_1x1 = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3a_1x1_bn')(inception_3a_1x1)
inception_3a_1x1 = Activation('relu')(inception_3a_1x1)

inception_3a = concatenate([inception_3a_3x3, inception_3a_5x5, inception_3a_pool, inception_3a_1x1], axis=3)

# Inception3b
inception_3b_3x3 = Conv2D(96, (1, 1), name='inception_3b_3x3_conv1')(inception_3a)
inception_3b_3x3 = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3b_3x3_bn1')(inception_3b_3x3)
inception_3b_3x3 = Activation('relu')(inception_3b_3x3)
inception_3b_3x3 = ZeroPadding2D(padding=(1, 1))(inception_3b_3x3)
inception_3b_3x3 = Conv2D(128, (3, 3), name='inception_3b_3x3_conv2')(inception_3b_3x3)
inception_3b_3x3 = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3b_3x3_bn2')(inception_3b_3x3)
inception_3b_3x3 = Activation('relu')(inception_3b_3x3)

inception_3b_5x5 = Conv2D(32, (1, 1), name='inception_3b_5x5_conv1')(inception_3a)
inception_3b_5x5 = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3b_5x5_bn1')(inception_3b_5x5)
inception_3b_5x5 = Activation('relu')(inception_3b_5x5)
inception_3b_5x5 = ZeroPadding2D(padding=(2, 2))(inception_3b_5x5)
inception_3b_5x5 = Conv2D(64, (5, 5), name='inception_3b_5x5_conv2')(inception_3b_5x5)
inception_3b_5x5 = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3b_5x5_bn2')(inception_3b_5x5)
inception_3b_5x5 = Activation('relu')(inception_3b_5x5)

inception_3b_pool = Lambda(lambda x: x**2, name='power2_3b')(inception_3a)
inception_3b_pool = AveragePooling2D(pool_size=(3, 3), strides=(3, 3))(inception_3b_pool)
inception_3b_pool = Lambda(lambda x: x*9, name='mult9_3b')(inception_3b_pool)
inception_3b_pool = Lambda(lambda x: K.sqrt(x), name='sqrt_3b')(inception_3b_pool)
inception_3b_pool = Conv2D(64, (1, 1), name='inception_3b_pool_conv')(inception_3b_pool)
inception_3b_pool = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3b_pool_bn')(inception_3b_pool)
inception_3b_pool = Activation('relu')(inception_3b_pool)
inception_3b_pool = ZeroPadding2D(padding=(4, 4))(inception_3b_pool)

inception_3b_1x1 = Conv2D(64, (1, 1), name='inception_3b_1x1_conv')(inception_3a)
inception_3b_1x1 = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3b_1x1_bn')(inception_3b_1x1)
inception_3b_1x1 = Activation('relu')(inception_3b_1x1)

inception_3b = concatenate([inception_3b_3x3, inception_3b_5x5, inception_3b_pool, inception_3b_1x1], axis=3)

# Inception3c
inception_3c_3x3 = utils.conv2d_bn(inception_3b,
                                   layer='inception_3c_3x3',
                                   cv1_out=128,
                                   cv1_filter=(1, 1),
                                   cv2_out=256,
                                   cv2_filter=(3, 3),
                                   cv2_strides=(2, 2),
                                   padding=(1, 1))

inception_3c_5x5 = utils.conv2d_bn(inception_3b,
                                   layer='inception_3c_5x5',
                                   cv1_out=32,
                                   cv1_filter=(1, 1),
                                   cv2_out=64,
                                   cv2_filter=(5, 5),
                                   cv2_strides=(2, 2),
                                   padding=(2, 2))

inception_3c_pool = MaxPooling2D(pool_size=3, strides=2)(inception_3b)
inception_3c_pool = ZeroPadding2D(padding=((0, 1), (0, 1)))(inception_3c_pool)

inception_3c = concatenate([inception_3c_3x3, inception_3c_5x5, inception_3c_pool], axis=3)

#inception 4a
inception_4a_3x3 = utils.conv2d_bn(inception_3c,
                                   layer='inception_4a_3x3',
                                   cv1_out=96,
                                   cv1_filter=(1, 1),
                                   cv2_out=192,
                                   cv2_filter=(3, 3),
                                   cv2_strides=(1, 1),
                                   padding=(1, 1))
inception_4a_5x5 = utils.conv2d_bn(inception_3c,
                                   layer='inception_4a_5x5',
                                   cv1_out=32,
                                   cv1_filter=(1, 1),
                                   cv2_out=64,
                                   cv2_filter=(5, 5),
                                   cv2_strides=(1, 1),
                                   padding=(2, 2))

inception_4a_pool = Lambda(lambda x: x**2, name='power2_4a')(inception_3c)
inception_4a_pool = AveragePooling2D(pool_size=(3, 3), strides=(3, 3))(inception_4a_pool)
inception_4a_pool = Lambda(lambda x: x*9, name='mult9_4a')(inception_4a_pool)
inception_4a_pool = Lambda(lambda x: K.sqrt(x), name='sqrt_4a')(inception_4a_pool)
inception_4a_pool = utils.conv2d_bn(inception_4a_pool,
                                   layer='inception_4a_pool',
                                   cv1_out=128,
                                   cv1_filter=(1, 1),
                                   padding=(2, 2))
inception_4a_1x1 = utils.conv2d_bn(inception_3c,
                                   layer='inception_4a_1x1',
                                   cv1_out=256,
                                   cv1_filter=(1, 1))
inception_4a = concatenate([inception_4a_3x3, inception_4a_5x5, inception_4a_pool, inception_4a_1x1], axis=3)

#inception4e
inception_4e_3x3 = utils.conv2d_bn(inception_4a,
                                   layer='inception_4e_3x3',
                                   cv1_out=160,
                                   cv1_filter=(1, 1),
                                   cv2_out=256,
                                   cv2_filter=(3, 3),
                                   cv2_strides=(2, 2),
                                   padding=(1, 1))
inception_4e_5x5 = utils.conv2d_bn(inception_4a,
                                   layer='inception_4e_5x5',
                                   cv1_out=64,
                                   cv1_filter=(1, 1),
                                   cv2_out=128,
                                   cv2_filter=(5, 5),
                                   cv2_strides=(2, 2),
                                   padding=(2, 2))
inception_4e_pool = MaxPooling2D(pool_size=3, strides=2)(inception_4a)
inception_4e_pool = ZeroPadding2D(padding=((0, 1), (0, 1)))(inception_4e_pool)

inception_4e = concatenate([inception_4e_3x3, inception_4e_5x5, inception_4e_pool], axis=3)

#inception5a
inception_5a_3x3 = utils.conv2d_bn(inception_4e,
                                   layer='inception_5a_3x3',
                                   cv1_out=96,
                                   cv1_filter=(1, 1),
                                   cv2_out=384,
                                   cv2_filter=(3, 3),
                                   cv2_strides=(1, 1),
                                   padding=(1, 1))

inception_5a_pool = Lambda(lambda x: x**2, name='power2_5a')(inception_4e)
inception_5a_pool = AveragePooling2D(pool_size=(3, 3), strides=(3, 3))(inception_5a_pool)
inception_5a_pool = Lambda(lambda x: x*9, name='mult9_5a')(inception_5a_pool)
inception_5a_pool = Lambda(lambda x: K.sqrt(x), name='sqrt_5a')(inception_5a_pool)
inception_5a_pool = utils.conv2d_bn(inception_5a_pool,
                                   layer='inception_5a_pool',
                                   cv1_out=96,
                                   cv1_filter=(1, 1),
                                   padding=(1, 1))
inception_5a_1x1 = utils.conv2d_bn(inception_4e,
                                   layer='inception_5a_1x1',
                                   cv1_out=256,
                                   cv1_filter=(1, 1))

inception_5a = concatenate([inception_5a_3x3, inception_5a_pool, inception_5a_1x1], axis=3)

#inception_5b
inception_5b_3x3 = utils.conv2d_bn(inception_5a,
                                   layer='inception_5b_3x3',
                                   cv1_out=96,
                                   cv1_filter=(1, 1),
                                   cv2_out=384,
                                   cv2_filter=(3, 3),
                                   cv2_strides=(1, 1),
                                   padding=(1, 1))
inception_5b_pool = MaxPooling2D(pool_size=3, strides=2)(inception_5a)
inception_5b_pool = utils.conv2d_bn(inception_5b_pool,
                                   layer='inception_5b_pool',
                                   cv1_out=96,
                                   cv1_filter=(1, 1))
inception_5b_pool = ZeroPadding2D(padding=(1, 1))(inception_5b_pool)

inception_5b_1x1 = utils.conv2d_bn(inception_5a,
                                   layer='inception_5b_1x1',
                                   cv1_out=256,
                                   cv1_filter=(1, 1))
inception_5b = concatenate([inception_5b_3x3, inception_5b_pool, inception_5b_1x1], axis=3)

av_pool = AveragePooling2D(pool_size=(3, 3), strides=(1, 1))(inception_5b)
reshape_layer = Flatten()(av_pool)
dense_layer = Dense(128, name='dense_layer')(reshape_layer)
norm_layer = Lambda(lambda  x: K.l2_normalize(x, axis=1), name='norm_layer')(dense_layer)


# Final Model
model = Model(inputs=[myInput], outputs=norm_layer)
# Out:
# WARNING:tensorflow:From C:\Users\Ocean\Anaconda2\envs\py36\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %% [markdown]
# # Carregar o modelo com pesos pré-treinados
#
# A FaceNet é treinado minimizado o triplet loss. Será carregado um modelo previamente treinado.

# %%
# Load weights from csv files (which was exported from Openface torch model)
weights = utils.weights
weights_dict = utils.load_weights()

# Set layer weights of the model
for name in weights:
  if model.get_layer(name) != None:
    model.get_layer(name).set_weights(weights_dict[name])
  elif model.get_layer(name) != None:
    model.get_layer(name).set_weights(weights_dict[name])

# %% [markdown]
# ## Função <font color=blue>image_to_embedding</font>
#
# Quando o modelo é carregado com pesos pré-treinados, pode-se criar os **128 vetores dimensionais embedding** para todas as faces salvas na pasta "images".
#
# A função **"image_to_embedding"** passa uma imagem pro modelo Inception, para gerar os vetores embedding.

# %%
def image_to_embedding(image, model):
    #image = cv2.resize(image, (96, 96), interpolation=cv2.INTER_AREA) 
    image = cv2.resize(image, (96, 96)) 
    img = image[...,::-1]
    img = np.around(np.transpose(img, (0,1,2))/255.0, decimals=12)
    x_train = np.array([img])
    embedding = model.predict_on_batch(x_train)
    return embedding

# %% [markdown]
# ## Função <font color=blue>recognize_face</font>
#
# Essa função calcula a similaridade entre a imagem capturado e as imagens que já estão armazenadas. Passa a imagem para o modelo de rede neural pré-treinado para gerar o vetor embedding. Este vetor será comparado com todos os outros vetores embeddings das imagens salvas, por meio da distância euclidiana L2.
#
# Se a mínima distância de L2 entre dois vetores embedding for menor do que o treshold (aqui o valor de treshold foi de .68, podendo ser ajustado) então serão correspondentes.

# %%
def recognize_face(face_image, input_embeddings, model):

    embedding = image_to_embedding(face_image, model)
    
    minimum_distance = 200
    name = None
    
    for(input_name, input_embedding) in input_embeddings.items():    
        euclidean_distance = np.linalg.norm(embedding-input_embedding)
        print('Euclidean distance from %s is %s' %(input_name, euclidean_distance))

        if(euclidean_distance < minimum_distance):
            minimum_distance = euclidean_distance
            name = input_name
    
    if(minimum_distance < 0.68):
        return str(name)
    else:
        return None

# %% [markdown]
# ## Função <font color=blue>create_input_image_embeddings</font>
#
# Essa função gera imagens embedding com dimensão de 128 para todas as imagens salvas na pasta "images" atráves da rede neural treinada. Cria um dicionário com o nome da imagem sendo a chave e os valores sendo o embedding.
#
# ## Função <font color=blue>recognize_faces_in_cam</font>
#
# Essa função captura a imagem através da webcam, detectar a face e cortar a imagem para ter somente a face, em seguida é passada para a função <font color=blue>recognize_face</font>.

# %%
import glob

def create_input_image_embeddings():
    input_embeddings = {}

    for file in glob.glob("images/*"):
        person_name = os.path.splitext(os.path.basename(file))[0]
        image_file = cv2.imread(file, 1)
        input_embeddings[person_name] = image_to_embedding(image_file, model)

    return input_embeddings

def recognize_faces_in_cam(input_embeddings):
    

    cv2.namedWindow("Face Recognizer")
    vc = cv2.VideoCapture(0)
   

    font = cv2.FONT_HERSHEY_SIMPLEX
    face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
    
    
    while vc.isOpened():
        _, frame = vc.read()
        img = frame
        height, width, channels = frame.shape

        
        
        gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        faces = face_cascade.detectMultiScale(gray, 1.3, 5)

        # Loop through all the faces detected 
        identities = []
        for (x, y, w, h) in faces:
            x1 = x
            y1 = y
            x2 = x+w
            y2 = y+h

           
            
            face_image = frame[max(0, y1):min(height, y2), max(0, x1):min(width, x2)]    
            identity = recognize_face(face_image, input_embeddings, model)
            
            

            if identity is not None:
                img = cv2.rectangle(frame,(x1, y1),(x2, y2),(255,255,255),2)
                cv2.putText(img, str(identity), (x1+5,y1-5), font, 1, (255,255,255), 2)
        
        key = cv2.waitKey(100)
        cv2.imshow("Face Recognizer", img)

        if key == 27: #saída no ESC
            break
    vc.release()
    cv2.destroyAllWindows()

# %% [markdown]
# ## Capturar faces
#
# O seguinte código captura 10 imagens de uma pessoa. Elas são salvas na pasta "images" com o nome de User_1 até User_10. Selecione a melhor imagem das 10. Renomeie a foto com o nome dela, e apague o resto das imagens. Essa imagem será utilizada para reconhecer a face da pessoa através do One Shot Learning.

# %%
cam = cv2.VideoCapture(0)

face_detector = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

count = 0
while(True):
    ret, img = cam.read()
    faces = face_detector.detectMultiScale(img, 1.3, 5)
    for (x,y,w,h) in faces:
        x1 = x
        y1 = y
        x2 = x+w
        y2 = y+h
        cv2.rectangle(img, (x1,y1), (x2,y2), (255,255,255), 2)     
        count += 1
        # Salvar as imagens dentro da pasta 'images'
        cv2.imwrite("images/User_" + str(count) + ".jpg", img[y1:y2,x1:x2])
        cv2.imshow('image', img)
    k = cv2.waitKey(200) & 0xff #saída no ESC
    if k == 27:
        break
    elif count >= 10:
         break
cam.release()
cv2.destroyAllWindows()

# %%
input_embeddings = create_input_image_embeddings()
recognize_faces_in_cam(input_embeddings)
# Out:
# Euclidean distance from Joao is 1.0147331
# Euclidean distance from Kid is 0.62043756
# Euclidean distance from Lucas is 1.0089153
# Euclidean distance from Joao is 1.0346215
# Euclidean distance from Kid is 0.90350384
# Euclidean distance from Lucas is 0.88859904
# Euclidean distance from Joao is 0.9535593
# Euclidean distance from Kid is 0.85978097
# Euclidean distance from Lucas is 0.8283002
# Euclidean distance from Joao is 0.88107413
# Euclidean distance from Kid is 0.7210456
# Euclidean distance from Lucas is 1.1444631
# Euclidean distance from Joao is 0.980595
# Euclidean distance from Kid is 0.6453441
# Euclidean distance from Lucas is 1.0660716
# Euclidean distance from Joao is 1.0337985
# Euclidean distance from Kid is 0.7050699
# Euclidean distance from Lucas is 0.9650566
# Euclidean distance from Joao is 0.94804245
# Euclidean distance from Kid is 0.67753327
# Euclidean distance from Lucas is 0.88053787
# Euclidean distance from Joao is 0.92779815
# Euclidean distance from Kid is 0.7437625
# Euclidean distance from Lucas is 1.025752
# Euclidean distance from Joao is 0.9352021
# Euclidean distance from Kid is 0.7182574
# Euclidean distance from Lucas is 0.8650034
# Euclidean distance from Joao is 0.96724945
# Euclidean distance from Kid is 0.731308
# Euclidean distance from Lucas is 0.90516245
# Euclidean distance from Joao is 0.9594461
# Euclidean distance from Kid is 0.7394985
# Euclidean distance from Lucas is 0.9395878
# Euclidean distance from Joao is 0.9885639
# Euclidean distance from Kid is 0.70669067
# Euclidean distance from Lucas is 0.9401908
# Euclidean distance from Joao is 0.95733505
# Euclidean distance from Kid is 0.7251889
# Euclidean distance from Lucas is 0.9474354
# Euclidean distance from Joao is 0.94946486
# Euclidean distance from Kid is 0.7571531
# Euclidean distance from Lucas is 0.9758476
# Euclidean distance from Joao is 0.9504452
# Euclidean distance from Kid is 0.689995
# Euclidean distance from Lucas is 0.94928974
# Euclidean distance from Joao is 0.9303942
# Euclidean distance from Kid is 0.6724806
# Euclidean distance from Lucas is 0.9599331
# Euclidean distance from Joao is 0.8924853
# Euclidean distance from Kid is 0.7147724
# Euclidean distance from Lucas is 0.9632428
# Euclidean distance from Joao is 0.8996919
# Euclidean distance from Kid is 0.66487247
# Euclidean distance from Lucas is 0.9663923
# Euclidean distance from Joao is 0.9533919
# Euclidean distance from Kid is 0.61139566
# Euclidean distance from Lucas is 0.968321
# Euclidean distance from Joao is 0.9962486
# Euclidean distance from Kid is 0.7205791
# Euclidean distance from Lucas is 1.1312324
# Euclidean distance from Joao is 0.9341077
# Euclidean distance from Kid is 0.6642474
# Euclidean distance from Lucas is 1.0245168
# Euclidean distance from Joao is 1.0345277
# Euclidean distance from Kid is 0.7178098
# Euclidean distance from Lucas is 1.0903015
# Euclidean distance from Joao is 1.0912089
# Euclidean distance from Kid is 0.7322337
# Euclidean distance from Lucas is 1.1046305
# Euclidean distance from Joao is 1.0360165
# Euclidean distance from Kid is 0.7567548
# Euclidean distance from Lucas is 1.0717915
# Euclidean distance from Joao is 1.0772544
# Euclidean distance from Kid is 0.7120422
# Euclidean distance from Lucas is 1.1117951
# Euclidean distance from Joao is 1.0087258
# Euclidean distance from Kid is 0.7518356
# Euclidean distance from Lucas is 1.1230098
# Euclidean distance from Joao is 1.0460604
# Euclidean distance from Kid is 0.6958429
# Euclidean distance from Lucas is 1.0991697
# Euclidean distance from Joao is 1.0193315
# Euclidean distance from Kid is 0.7249024
# Euclidean distance from Lucas is 1.0980983
# Euclidean distance from Joao is 0.9901454
# Euclidean distance from Kid is 0.62587565
# Euclidean distance from Lucas is 1.0371344
# Euclidean distance from Joao is 0.93685025
# Euclidean distance from Kid is 0.82164776
# Euclidean distance from Lucas is 1.0954489
# Euclidean distance from Joao is 0.9993326
# Euclidean distance from Kid is 0.8498057
# Euclidean distance from Lucas is 1.1551905
# Euclidean distance from Joao is 0.9807263
# Euclidean distance from Kid is 0.84658617
# Euclidean distance from Lucas is 1.0252014
# Euclidean distance from Joao is 0.97053427
# Euclidean distance from Kid is 0.8446212
# Euclidean distance from Lucas is 0.96448016
# Euclidean distance from Joao is 0.9669792
# Euclidean distance from Kid is 0.8269682
# Euclidean distance from Lucas is 0.9695455
# Euclidean distance from Joao is 0.9610801
# Euclidean distance from Kid is 0.8383077
# Euclidean distance from Lucas is 0.92776465
# Euclidean distance from Joao is 0.8794572
# Euclidean distance from Kid is 0.7005568
# Euclidean distance from Lucas is 0.941005
# Euclidean distance from Joao is 0.9937956
# Euclidean distance from Kid is 0.82748705
# Euclidean distance from Lucas is 0.9332823
# Euclidean distance from Joao is 0.94121134
# Euclidean distance from Kid is 0.75218755
# Euclidean distance from Lucas is 0.93977284
# Euclidean distance from Joao is 0.96814007
# Euclidean distance from Kid is 0.8012033
# Euclidean distance from Lucas is 1.0199519
# Euclidean distance from Joao is 0.9753582
# Euclidean distance from Kid is 0.66550297
# Euclidean distance from Lucas is 0.9306889
# Euclidean distance from Joao is 0.95394564
# Euclidean distance from Kid is 0.621568
# Euclidean distance from Lucas is 0.87694436
# Euclidean distance from Joao is 0.9383446
# Euclidean distance from Kid is 0.6587721
# Euclidean distance from Lucas is 0.89822227
# Euclidean distance from Joao is 1.075352
# Euclidean distance from Kid is 0.7698205
# Euclidean distance from Lucas is 0.8254552
# Euclidean distance from Joao is 0.9820761
# Euclidean distance from Kid is 0.6987413
# Euclidean distance from Lucas is 0.9159221
# Euclidean distance from Joao is 1.0177625
# Euclidean distance from Kid is 0.69183755
# Euclidean distance from Lucas is 0.7624324
# Euclidean distance from Joao is 1.0315318
# Euclidean distance from Kid is 0.79610384
# Euclidean distance from Lucas is 0.65039754
# Euclidean distance from Joao is 1.0696948
# Euclidean distance from Kid is 0.843228
# Euclidean distance from Lucas is 0.8310287
# Euclidean distance from Joao is 1.111137
# Euclidean distance from Kid is 0.8405979
# Euclidean distance from Lucas is 0.7825706
# Euclidean distance from Joao is 1.0690252
# Euclidean distance from Kid is 0.67717594
# Euclidean distance from Lucas is 0.825237
# Euclidean distance from Joao is 1.0695467
# Euclidean distance from Kid is 0.7797473
# Euclidean distance from Lucas is 0.77220136
# Euclidean distance from Joao is 1.0323737
# Euclidean distance from Kid is 0.64095515
# Euclidean distance from Lucas is 0.85044235
# Euclidean distance from Joao is 1.001417
# Euclidean distance from Kid is 0.677383
# Euclidean distance from Lucas is 0.8017802
# Euclidean distance from Joao is 1.0690756
# Euclidean distance from Kid is 0.62854475
# Euclidean distance from Lucas is 0.92200667
# Euclidean distance from Joao is 1.0505584
# Euclidean distance from Kid is 0.7043395
# Euclidean distance from Lucas is 0.7694417
# Euclidean distance from Joao is 1.0751042
# Euclidean distance from Kid is 0.74710524
# Euclidean distance from Lucas is 0.89008015
# Euclidean distance from Joao is 1.0793822
# Euclidean distance from Kid is 0.7517036
# Euclidean distance from Lucas is 0.9657312
# Euclidean distance from Joao is 1.073211
# Euclidean distance from Kid is 0.69204354
# Euclidean distance from Lucas is 0.9453806
# Euclidean distance from Joao is 1.0698327
# Euclidean distance from Kid is 0.6791349
# Euclidean distance from Lucas is 0.8870891
# Euclidean distance from Joao is 1.0145622
# Euclidean distance from Kid is 0.720381
# Euclidean distance from Lucas is 0.9020118
# Euclidean distance from Joao is 1.0076433
# Euclidean distance from Kid is 0.61017555
# Euclidean distance from Lucas is 0.8849807
# Euclidean distance from Joao is 1.0109605
# Euclidean distance from Kid is 0.6591579
# Euclidean distance from Lucas is 0.9478528
# Euclidean distance from Joao is 1.0709754
# Euclidean distance from Kid is 0.6584584
# Euclidean distance from Lucas is 0.8823397
# Euclidean distance from Joao is 1.0623398
# Euclidean distance from Kid is 0.67042893
# Euclidean distance from Lucas is 0.95524156
# Euclidean distance from Joao is 1.0399376
# Euclidean distance from Kid is 0.604245
# Euclidean distance from Lucas is 0.9551796
# Euclidean distance from Joao is 1.013905
# Euclidean distance from Kid is 0.59789205
# Euclidean distance from Lucas is 0.91162205
# Euclidean distance from Joao is 1.0014731
# Euclidean distance from Kid is 0.61412984
# Euclidean distance from Lucas is 1.0231913
# Euclidean distance from Joao is 1.0478309
# Euclidean distance from Kid is 0.6096788
# Euclidean distance from Lucas is 1.0376922
# Euclidean distance from Joao is 1.0788556
# Euclidean distance from Kid is 0.7237765
# Euclidean distance from Lucas is 0.9111204
# Euclidean distance from Joao is 1.0116179
# Euclidean distance from Kid is 0.6139295
# Euclidean distance from Lucas is 0.97861284
# Euclidean distance from Joao is 0.985214
# Euclidean distance from Kid is 0.48942184
# Euclidean distance from Lucas is 1.0293982
# Euclidean distance from Joao is 1.1322205
# Euclidean distance from Kid is 0.6903083
# Euclidean distance from Lucas is 1.0146552
# Euclidean distance from Joao is 0.9884174
# Euclidean distance from Kid is 0.6677921
# Euclidean distance from Lucas is 0.9137114
# Euclidean distance from Joao is 0.93624836
# Euclidean distance from Kid is 0.54265094
# Euclidean distance from Lucas is 0.94918615
# Euclidean distance from Joao is 1.0076479
# Euclidean distance from Kid is 0.60276824
# Euclidean distance from Lucas is 0.9439432
# Euclidean distance from Joao is 1.1041183
# Euclidean distance from Kid is 0.77691925
# Euclidean distance from Lucas is 0.7924933
# Euclidean distance from Joao is 1.0149918
# Euclidean distance from Kid is 0.7879245
# Euclidean distance from Lucas is 0.747171
# Euclidean distance from Joao is 1.0493025
# Euclidean distance from Kid is 0.6697372
# Euclidean distance from Lucas is 0.8502969
# Euclidean distance from Joao is 1.0414207
# Euclidean distance from Kid is 0.69842446
# Euclidean distance from Lucas is 0.8144681
# Euclidean distance from Joao is 0.9516345
# Euclidean distance from Kid is 0.55271846
# Euclidean distance from Lucas is 0.97282326
# Euclidean distance from Joao is 0.77905923
# Euclidean distance from Kid is 0.5996876
# Euclidean distance from Lucas is 0.8344008
# Euclidean distance from Joao is 0.8662658
# Euclidean distance from Kid is 0.5647955
# Euclidean distance from Lucas is 0.85751134
# Euclidean distance from Joao is 0.7963574
# Euclidean distance from Kid is 0.45389962
# Euclidean distance from Lucas is 0.913342
# Euclidean distance from Joao is 0.8904805
# Euclidean distance from Kid is 0.5288627
# Euclidean distance from Lucas is 0.97506136
# Euclidean distance from Joao is 0.98031497
# Euclidean distance from Kid is 0.52231014
# Euclidean distance from Lucas is 1.0720555
# Euclidean distance from Joao is 0.9458721
# Euclidean distance from Kid is 0.5553516
# Euclidean distance from Lucas is 0.94240385
# Euclidean distance from Joao is 0.99949163
# Euclidean distance from Kid is 0.52350056
# Euclidean distance from Lucas is 1.0465772
# Euclidean distance from Joao is 0.91183245
# Euclidean distance from Kid is 0.5726154
# Euclidean distance from Lucas is 0.9294389
# Euclidean distance from Joao is 0.8200688
# Euclidean distance from Kid is 0.74566156
# Euclidean distance from Lucas is 0.97030276
# Euclidean distance from Joao is 0.849307
# Euclidean distance from Kid is 0.80056626
# Euclidean distance from Lucas is 1.0246556
# Euclidean distance from Joao is 0.9639742
# Euclidean distance from Kid is 0.64183825
# Euclidean distance from Lucas is 0.8451263
# Euclidean distance from Joao is 0.86656946
# Euclidean distance from Kid is 0.6197761
# Euclidean distance from Lucas is 0.977109
# Euclidean distance from Joao is 0.77690196
# Euclidean distance from Kid is 0.7194034
# Euclidean distance from Lucas is 0.99592936
# Euclidean distance from Joao is 0.85705364
# Euclidean distance from Kid is 0.62759364
# Euclidean distance from Lucas is 0.9743525
# Euclidean distance from Joao is 0.814585
# Euclidean distance from Kid is 0.5817865
# Euclidean distance from Lucas is 0.9895451
# Euclidean distance from Joao is 0.85338134
# Euclidean distance from Kid is 0.6938243
# Euclidean distance from Lucas is 1.0640769
# Euclidean distance from Joao is 0.85933
# Euclidean distance from Kid is 0.8117812
# Euclidean distance from Lucas is 0.9428718
# Euclidean distance from Joao is 0.940861
# Euclidean distance from Kid is 0.7260066
# Euclidean distance from Lucas is 0.8642571
# Euclidean distance from Joao is 0.92599547
# Euclidean distance from Kid is 0.6559019
# Euclidean distance from Lucas is 0.8533115
# Euclidean distance from Joao is 0.94608986
# Euclidean distance from Kid is 0.66276956
# Euclidean distance from Lucas is 0.9813864
# Euclidean distance from Joao is 0.8928643
# Euclidean distance from Kid is 0.6361546
# Euclidean distance from Lucas is 0.92855805
# Euclidean distance from Joao is 0.95669407
# Euclidean distance from Kid is 0.7400293
# Euclidean distance from Lucas is 0.9116497
# Euclidean distance from Joao is 0.8902481
# Euclidean distance from Kid is 0.6817571
# Euclidean distance from Lucas is 0.9410038
# Euclidean distance from Joao is 0.8238258
# Euclidean distance from Kid is 0.6632798
# Euclidean distance from Lucas is 0.90059906
# Euclidean distance from Joao is 0.9439633
# Euclidean distance from Kid is 0.80652297
# Euclidean distance from Lucas is 0.97196954
# Euclidean distance from Joao is 0.97450864
# Euclidean distance from Kid is 0.86963207
# Euclidean distance from Lucas is 0.9227265
# Euclidean distance from Joao is 0.9758293
# Euclidean distance from Kid is 0.64562297
# Euclidean distance from Lucas is 0.9300539
# Euclidean distance from Joao is 0.98576903
# Euclidean distance from Kid is 0.6896343
# Euclidean distance from Lucas is 0.9830094
# Euclidean distance from Joao is 0.8811147
# Euclidean distance from Kid is 0.6020293
# Euclidean distance from Lucas is 0.9545535
# Euclidean distance from Joao is 1.0011353
# Euclidean distance from Kid is 0.87269735
# Euclidean distance from Lucas is 0.91797477
# Euclidean distance from Joao is 0.92606014
# Euclidean distance from Kid is 0.9195477
# Euclidean distance from Lucas is 1.0724046
# Euclidean distance from Joao is 0.9709326
# Euclidean distance from Kid is 0.88030493
# Euclidean distance from Lucas is 0.940907
# Euclidean distance from Joao is 0.9646466
# Euclidean distance from Kid is 0.7703407
# Euclidean distance from Lucas is 0.7901546
# Euclidean distance from Joao is 1.1420484
# Euclidean distance from Kid is 1.1173993
# Euclidean distance from Lucas is 0.8865008
# Euclidean distance from Joao is 1.1918622
# Euclidean distance from Kid is 1.2143432
# Euclidean distance from Lucas is 0.85125506
# Euclidean distance from Joao is 1.176165
# Euclidean distance from Kid is 0.9954536
# Euclidean distance from Lucas is 0.7687708
# Euclidean distance from Joao is 0.97004414
# Euclidean distance from Kid is 0.6206872
# Euclidean distance from Lucas is 1.0335789
# Euclidean distance from Joao is 0.93242866
# Euclidean distance from Kid is 0.86440384
# Euclidean distance from Lucas is 0.9991661
# Euclidean distance from Joao is 0.9445095
# Euclidean distance from Kid is 0.7562555
# Euclidean distance from Lucas is 1.079741
# Euclidean distance from Joao is 0.9174481
# Euclidean distance from Kid is 0.65531814
# Euclidean distance from Lucas is 0.96901304
# Euclidean distance from Joao is 0.89442074
# Euclidean distance from Kid is 0.6291766
# Euclidean distance from Lucas is 1.0521584
# Euclidean distance from Joao is 0.9331768
# Euclidean distance from Kid is 0.71383446
# Euclidean distance from Lucas is 1.0559664
# Euclidean distance from Joao is 0.8937787
# Euclidean distance from Kid is 0.65533245
# Euclidean distance from Lucas is 0.8521432
# Euclidean distance from Joao is 0.90284437
# Euclidean distance from Kid is 0.6362903
# Euclidean distance from Lucas is 0.80306524
# Euclidean distance from Joao is 0.895004
# Euclidean distance from Kid is 0.5884805
# Euclidean distance from Lucas is 1.0306846
# Euclidean distance from Joao is 0.85492647
# Euclidean distance from Kid is 0.5461401
# Euclidean distance from Lucas is 0.95136553
# Euclidean distance from Joao is 0.8856592
# Euclidean distance from Kid is 0.61573017
# Euclidean distance from Lucas is 1.0750077
# Euclidean distance from Joao is 1.2375758
# Euclidean distance from Kid is 1.0466317
# Euclidean distance from Lucas is 0.7500219
# Euclidean distance from Joao is 1.1390349
# Euclidean distance from Kid is 0.9541798
# Euclidean distance from Lucas is 0.74656385
# Euclidean distance from Joao is 1.0800542
# Euclidean distance from Kid is 0.9505176
# Euclidean distance from Lucas is 0.78622186
# Euclidean distance from Joao is 1.1279315
# Euclidean distance from Kid is 0.92068666
# Euclidean distance from Lucas is 0.81270397
# Euclidean distance from Joao is 1.0624113
# Euclidean distance from Kid is 0.73903567
# Euclidean distance from Lucas is 1.1485599
# Euclidean distance from Joao is 0.8841437
# Euclidean distance from Kid is 0.6531972
# Euclidean distance from Lucas is 1.0290768
# Euclidean distance from Joao is 0.8799819
# Euclidean distance from Kid is 0.7807723
# Euclidean distance from Lucas is 1.0521612
# Euclidean distance from Joao is 0.9198504
# Euclidean distance from Kid is 0.8703107
# Euclidean distance from Lucas is 1.0884595
# Euclidean distance from Joao is 1.004611
# Euclidean distance from Kid is 0.6182169
# Euclidean distance from Lucas is 1.0713063
# Euclidean distance from Joao is 0.94908434
# Euclidean distance from Kid is 0.68194324
# Euclidean distance from Lucas is 1.1061606
# Euclidean distance from Joao is 0.9958799
# Euclidean distance from Kid is 0.7333955
# Euclidean distance from Lucas is 1.0464647
# Euclidean distance from Joao is 0.9000121
# Euclidean distance from Kid is 0.8273594
# Euclidean distance from Lucas is 1.0308619
# Euclidean distance from Joao is 1.0003474
# Euclidean distance from Kid is 0.75950795
# Euclidean distance from Lucas is 1.1032171
# Euclidean distance from Joao is 0.9545414
# Euclidean distance from Kid is 0.7489771
# Euclidean distance from Lucas is 1.0575479
# Euclidean distance from Joao is 1.0115952
# Euclidean distance from Kid is 0.9062235
# Euclidean distance from Lucas is 0.9219112
# Euclidean distance from Joao is 0.9132822
# Euclidean distance from Kid is 0.6791622
# Euclidean distance from Lucas is 1.010956
# Euclidean distance from Joao is 1.0405177
# Euclidean distance from Kid is 0.79137623
# Euclidean distance from Lucas is 0.8338826
# Euclidean distance from Joao is 0.8942221
# Euclidean distance from Kid is 0.6296535
# Euclidean distance from Lucas is 1.0661607
# Euclidean distance from Joao is 0.87310755
# Euclidean distance from Kid is 0.52297413
# Euclidean distance from Lucas is 0.92367977
# Euclidean distance from Joao is 0.9857636
# Euclidean distance from Kid is 0.5299929
# Euclidean distance from Lucas is 0.9179828
# Euclidean distance from Joao is 1.0182008
# Euclidean distance from Kid is 0.60696423
# Euclidean distance from Lucas is 1.0898137
# Euclidean distance from Joao is 0.980674
# Euclidean distance from Kid is 0.7686221
# Euclidean distance from Lucas is 1.0675716
# Euclidean distance from Joao is 1.1152581
# Euclidean distance from Kid is 0.8854188
# Euclidean distance from Lucas is 0.9541167
# Euclidean distance from Joao is 0.96497005
# Euclidean distance from Kid is 0.5910045
# Euclidean distance from Lucas is 1.0210611
# Euclidean distance from Joao is 1.0714054
# Euclidean distance from Kid is 0.7253411
# Euclidean distance from Lucas is 0.8202008
# Euclidean distance from Joao is 0.87938225
# Euclidean distance from Kid is 0.62640285
# Euclidean distance from Lucas is 0.9397549
# Euclidean distance from Joao is 0.9207955
# Euclidean distance from Kid is 0.5830231
# Euclidean distance from Lucas is 0.90511644
# Euclidean distance from Joao is 0.93876016
# Euclidean distance from Kid is 0.6161004
# Euclidean distance from Lucas is 0.84316546
# Euclidean distance from Joao is 0.9192496
# Euclidean distance from Kid is 0.69199044
# Euclidean distance from Lucas is 0.9174548
# Euclidean distance from Joao is 0.8718134
# Euclidean distance from Kid is 0.6422794
# Euclidean distance from Lucas is 1.0117885
# Euclidean distance from Joao is 0.91358864
# Euclidean distance from Kid is 0.6072954
# Euclidean distance from Lucas is 1.020856
# Euclidean distance from Joao is 0.904954
# Euclidean distance from Kid is 0.6628783
# Euclidean distance from Lucas is 0.990322
# Euclidean distance from Joao is 0.926168
# Euclidean distance from Kid is 0.6289112
# Euclidean distance from Lucas is 0.8967498
# Euclidean distance from Joao is 0.93075
# Euclidean distance from Kid is 0.6377318
# Euclidean distance from Lucas is 0.9337192
# Euclidean distance from Joao is 0.9412059
# Euclidean distance from Kid is 0.6098867
# Euclidean distance from Lucas is 1.0025921
# Euclidean distance from Joao is 1.0642968
# Euclidean distance from Kid is 0.7470026
# Euclidean distance from Lucas is 1.1130086
# Euclidean distance from Joao is 0.9678667
# Euclidean distance from Kid is 0.6441873
# Euclidean distance from Lucas is 1.0439361
# Euclidean distance from Joao is 0.9916357
# Euclidean distance from Kid is 0.81839144
# Euclidean distance from Lucas is 1.0455276
# Euclidean distance from Joao is 0.91904604
# Euclidean distance from Kid is 0.5072673
# Euclidean distance from Lucas is 0.9710807
# Euclidean distance from Joao is 0.9307525
# Euclidean distance from Kid is 0.60330904
# Euclidean distance from Lucas is 1.021596
# Euclidean distance from Joao is 0.8456441
# Euclidean distance from Kid is 0.56816316
# Euclidean distance from Lucas is 0.9993096
# Euclidean distance from Joao is 0.96194935
# Euclidean distance from Kid is 0.7225244
# Euclidean distance from Lucas is 1.0614245
# Euclidean distance from Joao is 0.9693955
# Euclidean distance from Kid is 0.5990545
# Euclidean distance from Lucas is 0.87804496
# Euclidean distance from Joao is 0.9030578
# Euclidean distance from Kid is 0.72484905
# Euclidean distance from Lucas is 1.1105739
# Euclidean distance from Joao is 0.9852166
# Euclidean distance from Kid is 0.7542097
# Euclidean distance from Lucas is 1.013402
# Euclidean distance from Joao is 1.0295196
# Euclidean distance from Kid is 0.7993175
# Euclidean distance from Lucas is 0.9458818
# Euclidean distance from Joao is 0.97985303
# Euclidean distance from Kid is 0.6400897
# Euclidean distance from Lucas is 0.98526484
# Euclidean distance from Joao is 0.87795466
# Euclidean distance from Kid is 0.6055382
# Euclidean distance from Lucas is 0.99205154
# Euclidean distance from Joao is 0.9043824
# Euclidean distance from Kid is 0.5412516
# Euclidean distance from Lucas is 0.9632362
# Euclidean distance from Joao is 0.91961074
# Euclidean distance from Kid is 0.7799557
# Euclidean distance from Lucas is 1.1381344
# Euclidean distance from Joao is 0.9891726
# Euclidean distance from Kid is 0.79005563
# Euclidean distance from Lucas is 1.0928253
# Euclidean distance from Joao is 0.9448039
# Euclidean distance from Kid is 0.70297366
# Euclidean distance from Lucas is 1.0061293
# Euclidean distance from Joao is 1.0438187
# Euclidean distance from Kid is 0.75173604
# Euclidean distance from Lucas is 0.9831586
# Euclidean distance from Joao is 0.8801048
# Euclidean distance from Kid is 0.65043294
# Euclidean distance from Lucas is 1.0352447
# Euclidean distance from Joao is 0.8901635
# Euclidean distance from Kid is 0.5475151
# Euclidean distance from Lucas is 1.0401053
# Euclidean distance from Joao is 0.8845359
# Euclidean distance from Kid is 0.5147528
# Euclidean distance from Lucas is 1.040849
# Euclidean distance from Joao is 0.88188744
# Euclidean distance from Kid is 0.61980844
# Euclidean distance from Lucas is 1.0199437
# Euclidean distance from Joao is 1.08268
# Euclidean distance from Kid is 0.69242257
# Euclidean distance from Lucas is 0.8865934
# Euclidean distance from Joao is 0.89527136
# Euclidean distance from Kid is 0.73031706
# Euclidean distance from Lucas is 1.0581436
# Euclidean distance from Joao is 0.99502796
# Euclidean distance from Kid is 0.85209465
# Euclidean distance from Lucas is 0.91374856
# Euclidean distance from Joao is 0.89037615
# Euclidean distance from Kid is 0.5731879
# Euclidean distance from Lucas is 0.8552616
# Euclidean distance from Joao is 0.9179246
# Euclidean distance from Kid is 0.5893474
# Euclidean distance from Lucas is 0.8522884
# Euclidean distance from Joao is 0.94109064
# Euclidean distance from Kid is 0.55764943
# Euclidean distance from Lucas is 0.9252789
# Euclidean distance from Joao is 0.95262516
# Euclidean distance from Kid is 0.6750627
# Euclidean distance from Lucas is 0.86182183
# Euclidean distance from Joao is 0.9169518
# Euclidean distance from Kid is 0.5441816
# Euclidean distance from Lucas is 0.82799697
# Euclidean distance from Joao is 0.9350133
# Euclidean distance from Kid is 0.6073633
# Euclidean distance from Lucas is 0.97753185
# Euclidean distance from Joao is 0.98431534
# Euclidean distance from Kid is 0.6619287
# Euclidean distance from Lucas is 0.847362
# Euclidean distance from Joao is 0.99877524
# Euclidean distance from Kid is 0.6915416
# Euclidean distance from Lucas is 0.8688988
# Euclidean distance from Joao is 1.1017284
# Euclidean distance from Kid is 0.7956485
# Euclidean distance from Lucas is 0.89495885
# Euclidean distance from Joao is 0.9632191
# Euclidean distance from Kid is 0.6338708
# Euclidean distance from Lucas is 0.9935495
# Euclidean distance from Joao is 0.95864
# Euclidean distance from Kid is 0.70802855
# Euclidean distance from Lucas is 0.9760672
# Euclidean distance from Joao is 0.9433316
# Euclidean distance from Kid is 0.6397809
# Euclidean distance from Lucas is 0.90160704
# Euclidean distance from Joao is 0.9190781
# Euclidean distance from Kid is 0.6912518
# Euclidean distance from Lucas is 0.9074516
# Euclidean distance from Joao is 0.99032414
# Euclidean distance from Kid is 0.77707666
# Euclidean distance from Lucas is 0.8836934
# Euclidean distance from Joao is 1.0124321
# Euclidean distance from Kid is 0.668902
# Euclidean distance from Lucas is 0.88205093
# Euclidean distance from Joao is 1.1211594
# Euclidean distance from Kid is 0.9881302
# Euclidean distance from Lucas is 0.9427389
# Euclidean distance from Joao is 0.9819701
# Euclidean distance from Kid is 0.5719414
# Euclidean distance from Lucas is 0.8550216
# Euclidean distance from Joao is 1.1138303
# Euclidean distance from Kid is 0.9884266
# Euclidean distance from Lucas is 0.9075064
# Euclidean distance from Joao is 1.0176449
# Euclidean distance from Kid is 0.8916369
# Euclidean distance from Lucas is 0.8314008
# Euclidean distance from Joao is 0.99135625
# Euclidean distance from Kid is 0.6992611
# Euclidean distance from Lucas is 0.7778452
# Euclidean distance from Joao is 1.0552535
# Euclidean distance from Kid is 0.8034458
# Euclidean distance from Lucas is 0.7573009
# Euclidean distance from Joao is 1.0800005
# Euclidean distance from Kid is 1.0249192
# Euclidean distance from Lucas is 0.84404445
# Euclidean distance from Joao is 0.99373966
# Euclidean distance from Kid is 0.8465544
# Euclidean distance from Lucas is 0.86205846
# Euclidean distance from Joao is 0.94968104
# Euclidean distance from Kid is 0.6809483
# Euclidean distance from Lucas is 0.817299
# Euclidean distance from Joao is 1.1718903
# Euclidean distance from Kid is 1.0588301
# Euclidean distance from Lucas is 0.79103833
# Euclidean distance from Joao is 0.9038203
# Euclidean distance from Kid is 0.88398665
# Euclidean distance from Lucas is 1.1251675
# Euclidean distance from Joao is 0.9964411
# Euclidean distance from Kid is 1.0307227
# Euclidean distance from Lucas is 1.2555156
# Euclidean distance from Joao is 0.93370354
# Euclidean distance from Kid is 0.938408
# Euclidean distance from Lucas is 1.1856939
# Euclidean distance from Joao is 0.96929014
# Euclidean distance from Kid is 0.8269261
# Euclidean distance from Lucas is 1.1510645
# Euclidean distance from Joao is 1.107973
# Euclidean distance from Kid is 0.86966217
# Euclidean distance from Lucas is 1.0389674
# Euclidean distance from Joao is 0.9220529
# Euclidean distance from Kid is 0.63557935
# Euclidean distance from Lucas is 0.89385545
# Euclidean distance from Joao is 1.2003906
# Euclidean distance from Kid is 0.9616405
# Euclidean distance from Lucas is 0.84354234
# Euclidean distance from Joao is 1.2051784
# Euclidean distance from Kid is 1.1040483
# Euclidean distance from Lucas is 0.75742364
# Euclidean distance from Joao is 1.2379745
# Euclidean distance from Kid is 1.2240696
# Euclidean distance from Lucas is 0.8731144
# Euclidean distance from Joao is 1.3559515
# Euclidean distance from Kid is 1.2095937
# Euclidean distance from Lucas is 0.7975077
# Euclidean distance from Joao is 1.229682
# Euclidean distance from Kid is 1.0139073
# Euclidean distance from Lucas is 0.7046076
# Euclidean distance from Joao is 1.2110219
# Euclidean distance from Kid is 1.1475879
# Euclidean distance from Lucas is 0.6574536
# Euclidean distance from Joao is 1.0200741
# Euclidean distance from Kid is 0.842588
# Euclidean distance from Lucas is 0.768753
# Euclidean distance from Joao is 1.1145698
# Euclidean distance from Kid is 0.9181398
# Euclidean distance from Lucas is 0.71587044
# Euclidean distance from Joao is 1.0185251
# Euclidean distance from Kid is 0.73596597
# Euclidean distance from Lucas is 0.736753
# Euclidean distance from Joao is 0.87864107
# Euclidean distance from Kid is 0.6920149
# Euclidean distance from Lucas is 0.8709592
# Euclidean distance from Joao is 0.8112521
# Euclidean distance from Kid is 0.6738204
# Euclidean distance from Lucas is 0.8624604
# Euclidean distance from Joao is 0.87934285
# Euclidean distance from Kid is 0.5990777
# Euclidean distance from Lucas is 0.9123788
# Euclidean distance from Joao is 0.8603748
# Euclidean distance from Kid is 0.65514773
# Euclidean distance from Lucas is 0.9439463
# Euclidean distance from Joao is 0.85517824
# Euclidean distance from Kid is 0.60171336
# Euclidean distance from Lucas is 0.940917
# Euclidean distance from Joao is 0.8730664
# Euclidean distance from Kid is 0.5972645
# Euclidean distance from Lucas is 0.90636075
# Euclidean distance from Joao is 0.8773032
# Euclidean distance from Kid is 0.6240048
# Euclidean distance from Lucas is 0.91547316
# Euclidean distance from Joao is 0.9144841
# Euclidean distance from Kid is 0.6810131
# Euclidean distance from Lucas is 0.89691246
# Euclidean distance from Joao is 0.90564024
# Euclidean distance from Kid is 0.62127066
# Euclidean distance from Lucas is 0.8891729
# Euclidean distance from Joao is 0.85845375
# Euclidean distance from Kid is 0.56193066
# Euclidean distance from Lucas is 0.9050722
# Euclidean distance from Joao is 0.8846865
# Euclidean distance from Kid is 0.66502494
# Euclidean distance from Lucas is 1.0134066
# Euclidean distance from Joao is 0.8747322
# Euclidean distance from Kid is 0.6974839
# Euclidean distance from Lucas is 0.9973135
# Euclidean distance from Joao is 0.9188263
# Euclidean distance from Kid is 0.67605823
# Euclidean distance from Lucas is 0.9220492
# Euclidean distance from Joao is 0.86467814
# Euclidean distance from Kid is 0.66824436
# Euclidean distance from Lucas is 0.84729844
# Euclidean distance from Joao is 0.93176264
# Euclidean distance from Kid is 0.68980557
# Euclidean distance from Lucas is 0.88648707
# Euclidean distance from Joao is 0.9747374
# Euclidean distance from Kid is 0.5915255
# Euclidean distance from Lucas is 0.94783497
# Euclidean distance from Joao is 0.8462374
# Euclidean distance from Kid is 0.6112992
# Euclidean distance from Lucas is 0.9078279
# Euclidean distance from Joao is 0.8592396
# Euclidean distance from Kid is 0.684034
# Euclidean distance from Lucas is 0.92081344
# Euclidean distance from Joao is 0.8793477
# Euclidean distance from Kid is 0.65006256
# Euclidean distance from Lucas is 0.94433236
# Euclidean distance from Joao is 0.9104674
# Euclidean distance from Kid is 0.58046967
# Euclidean distance from Lucas is 0.8688305
# Euclidean distance from Joao is 0.89367366
# Euclidean distance from Kid is 0.64011097
# Euclidean distance from Lucas is 0.96121603
# Euclidean distance from Joao is 0.87961704
# Euclidean distance from Kid is 0.6230789
# Euclidean distance from Lucas is 0.9645206
# Euclidean distance from Joao is 0.8644565
# Euclidean distance from Kid is 0.5808086
# Euclidean distance from Lucas is 0.9391657
# Euclidean distance from Joao is 0.86209655
# Euclidean distance from Kid is 0.5687369
# Euclidean distance from Lucas is 0.9951656
# Euclidean distance from Joao is 0.93763644
# Euclidean distance from Kid is 0.66498876
# Euclidean distance from Lucas is 0.88513297
# Euclidean distance from Joao is 0.79372233
# Euclidean distance from Kid is 0.63387656
# Euclidean distance from Lucas is 0.963768
# Euclidean distance from Joao is 0.8312212
# Euclidean distance from Kid is 0.6039757
# Euclidean distance from Lucas is 0.9357917
# Euclidean distance from Joao is 0.8106233
# Euclidean distance from Kid is 0.6121846
# Euclidean distance from Lucas is 0.87648803
# Euclidean distance from Joao is 0.93912727
# Euclidean distance from Kid is 0.61864513
# Euclidean distance from Lucas is 0.8944686
# Euclidean distance from Joao is 1.0059465
# Euclidean distance from Kid is 0.7174773
# Euclidean distance from Lucas is 0.9604137
# Euclidean distance from Joao is 0.91891545
# Euclidean distance from Kid is 0.7636159
# Euclidean distance from Lucas is 0.97936034
# Euclidean distance from Joao is 0.96331334
# Euclidean distance from Kid is 0.7306801
# Euclidean distance from Lucas is 0.806254
# Euclidean distance from Joao is 1.0061748
# Euclidean distance from Kid is 0.7889549
# Euclidean distance from Lucas is 0.94582176
# Euclidean distance from Joao is 1.0623046
# Euclidean distance from Kid is 0.9751487
# Euclidean distance from Lucas is 0.90451586
# Euclidean distance from Joao is 1.1474085
# Euclidean distance from Kid is 1.0307943
# Euclidean distance from Lucas is 0.8194213
# Euclidean distance from Joao is 1.0806793
# Euclidean distance from Kid is 0.94038415
# Euclidean distance from Lucas is 0.8624424
# Euclidean distance from Joao is 1.0929083
# Euclidean distance from Kid is 0.9124963
# Euclidean distance from Lucas is 0.89739615
# Euclidean distance from Joao is 1.1042669
# Euclidean distance from Kid is 0.93108904
# Euclidean distance from Lucas is 0.87765235
# Euclidean distance from Joao is 1.0037644
# Euclidean distance from Kid is 0.87378097
# Euclidean distance from Lucas is 0.9935852
# Euclidean distance from Joao is 1.003739
# Euclidean distance from Kid is 0.9263774
# Euclidean distance from Lucas is 1.0038809
# Euclidean distance from Joao is 1.0503235
# Euclidean distance from Kid is 0.8227586
# Euclidean distance from Lucas is 0.7796624
# Euclidean distance from Joao is 1.0283371
# Euclidean distance from Kid is 0.8016006
# Euclidean distance from Lucas is 0.80782646
# Euclidean distance from Joao is 1.0331205
# Euclidean distance from Kid is 0.8278225
# Euclidean distance from Lucas is 0.8366937
# Euclidean distance from Joao is 1.0290703
# Euclidean distance from Kid is 0.84746027
# Euclidean distance from Lucas is 0.82466286
# Euclidean distance from Joao is 1.0406507
# Euclidean distance from Kid is 0.8009958
# Euclidean distance from Lucas is 0.86368
# Euclidean distance from Joao is 1.0295349
# Euclidean distance from Kid is 0.800896
# Euclidean distance from Lucas is 0.8881949
# Euclidean distance from Joao is 1.090826
# Euclidean distance from Kid is 0.822064
# Euclidean distance from Lucas is 0.7392271
# Euclidean distance from Joao is 1.0886905
# Euclidean distance from Kid is 0.72088593
# Euclidean distance from Lucas is 0.7314365
# Euclidean distance from Joao is 1.1043044
# Euclidean distance from Kid is 0.78483975
# Euclidean distance from Lucas is 0.6601028
# Euclidean distance from Joao is 1.0676795
# Euclidean distance from Kid is 0.77830535
# Euclidean distance from Lucas is 0.7724829
# Euclidean distance from Joao is 1.0012448
# Euclidean distance from Kid is 0.8113228
# Euclidean distance from Lucas is 0.87089133
# Euclidean distance from Joao is 1.1748027
# Euclidean distance from Kid is 0.9251842
# Euclidean distance from Lucas is 0.7189787
# Euclidean distance from Joao is 0.9836839
# Euclidean distance from Kid is 0.73543537
# Euclidean distance from Lucas is 0.9068233
# Euclidean distance from Joao is 1.1587398
# Euclidean distance from Kid is 0.8812451
# Euclidean distance from Lucas is 0.7808746
# Euclidean distance from Joao is 1.1031566
# Euclidean distance from Kid is 0.84640175
# Euclidean distance from Lucas is 0.8867395
# Euclidean distance from Joao is 1.0515316
# Euclidean distance from Kid is 0.7954811
# Euclidean distance from Lucas is 0.89131236
# Euclidean distance from Joao is 0.95377785
# Euclidean distance from Kid is 0.631299
# Euclidean distance from Lucas is 0.89615434
# Euclidean distance from Joao is 1.0849708
# Euclidean distance from Kid is 0.78446764
# Euclidean distance from Lucas is 0.86178046
# Euclidean distance from Joao is 1.1525042
# Euclidean distance from Kid is 0.85630226
# Euclidean distance from Lucas is 0.7762728
# Euclidean distance from Joao is 1.1119783
# Euclidean distance from Kid is 0.81292355
# Euclidean distance from Lucas is 0.68787694
# Euclidean distance from Joao is 0.92485243
# Euclidean distance from Kid is 0.7324157
# Euclidean distance from Lucas is 0.8401536
# Euclidean distance from Joao is 0.9359716
# Euclidean distance from Kid is 0.7154405
# Euclidean distance from Lucas is 0.9018112
# Euclidean distance from Joao is 0.9695145
# Euclidean distance from Kid is 0.9487123
# Euclidean distance from Lucas is 1.0998287
# Euclidean distance from Joao is 0.84537154
# Euclidean distance from Kid is 0.69471824
# Euclidean distance from Lucas is 0.8865404
# Euclidean distance from Joao is 0.88406956
# Euclidean distance from Kid is 0.67180544
# Euclidean distance from Lucas is 1.0207024
# Euclidean distance from Joao is 1.0440733
# Euclidean distance from Kid is 0.6463419
# Euclidean distance from Lucas is 0.893186
# Euclidean distance from Joao is 0.98130465
# Euclidean distance from Kid is 0.8133125
# Euclidean distance from Lucas is 0.9708666
# Euclidean distance from Joao is 0.95002633
# Euclidean distance from Kid is 0.6178669
# Euclidean distance from Lucas is 0.9217942
# Euclidean distance from Joao is 0.89726895
# Euclidean distance from Kid is 0.54166794
# Euclidean distance from Lucas is 1.0341244
# Euclidean distance from Joao is 1.064668
# Euclidean distance from Kid is 0.6918722
# Euclidean distance from Lucas is 0.851856
# Euclidean distance from Joao is 0.93830425
# Euclidean distance from Kid is 0.75864846
# Euclidean distance from Lucas is 0.9934116
# Euclidean distance from Joao is 1.0796549
# Euclidean distance from Kid is 0.73823905
# Euclidean distance from Lucas is 0.8884935
# Euclidean distance from Joao is 0.972939
# Euclidean distance from Kid is 0.6561729
# Euclidean distance from Lucas is 0.8178701
# Euclidean distance from Joao is 0.93201745
# Euclidean distance from Kid is 0.63794124
# Euclidean distance from Lucas is 0.86853427
# Euclidean distance from Joao is 1.0565312
# Euclidean distance from Kid is 0.647985
# Euclidean distance from Lucas is 0.95637375
# Euclidean distance from Joao is 0.96395904
# Euclidean distance from Kid is 0.7214147
# Euclidean distance from Lucas is 0.8997665
# Euclidean distance from Joao is 1.0906484
# Euclidean distance from Kid is 0.7726383
# Euclidean distance from Lucas is 0.9088205
# Euclidean distance from Joao is 0.8532273
# Euclidean distance from Kid is 0.5074282
# Euclidean distance from Lucas is 0.92443913
# Euclidean distance from Joao is 1.0647866
# Euclidean distance from Kid is 0.6965
# Euclidean distance from Lucas is 0.7794404
# Euclidean distance from Joao is 0.9731954
# Euclidean distance from Kid is 0.62639827
# Euclidean distance from Lucas is 0.7817677
# Euclidean distance from Joao is 1.058374
# Euclidean distance from Kid is 0.7610481
# Euclidean distance from Lucas is 0.79910284
# Euclidean distance from Joao is 0.9494745
# Euclidean distance from Kid is 0.77570915
# Euclidean distance from Lucas is 0.88250196
# Euclidean distance from Joao is 1.0165114
# Euclidean distance from Kid is 0.67758876
# Euclidean distance from Lucas is 0.74210036
# Euclidean distance from Joao is 0.979884
# Euclidean distance from Kid is 0.731465
# Euclidean distance from Lucas is 0.7997415
# Euclidean distance from Joao is 1.0325612
# Euclidean distance from Kid is 0.81378734
# Euclidean distance from Lucas is 0.73680526
# Euclidean distance from Joao is 1.1169618
# Euclidean distance from Kid is 1.019733
# Euclidean distance from Lucas is 0.63777494
# Euclidean distance from Joao is 1.0637373
# Euclidean distance from Kid is 0.9020381
# Euclidean distance from Lucas is 0.7028502
# Euclidean distance from Joao is 1.0355532
# Euclidean distance from Kid is 0.7608327
# Euclidean distance from Lucas is 0.8340464
# Euclidean distance from Joao is 1.0364988
# Euclidean distance from Kid is 0.7315607
# Euclidean distance from Lucas is 0.84620094
# Euclidean distance from Joao is 1.0272388
# Euclidean distance from Kid is 0.7877849
# Euclidean distance from Lucas is 0.8934132
# Euclidean distance from Joao is 1.0610303
# Euclidean distance from Kid is 0.8312472
# Euclidean distance from Lucas is 0.78113365
# Euclidean distance from Joao is 1.068257
# Euclidean distance from Kid is 0.87851423
# Euclidean distance from Lucas is 0.72221285
# Euclidean distance from Joao is 1.0763903
# Euclidean distance from Kid is 0.88707525
# Euclidean distance from Lucas is 0.67848724
# Euclidean distance from Joao is 1.0131887
# Euclidean distance from Kid is 0.80431515
# Euclidean distance from Lucas is 0.7988507
# Euclidean distance from Joao is 0.9378017
# Euclidean distance from Kid is 0.7359622
# Euclidean distance from Lucas is 0.9039777
# Euclidean distance from Joao is 0.9370246
# Euclidean distance from Kid is 0.6902396
# Euclidean distance from Lucas is 0.8763193
# Euclidean distance from Joao is 0.89265907
# Euclidean distance from Kid is 0.7487821
# Euclidean distance from Lucas is 0.8546887
# Euclidean distance from Joao is 0.96657246
# Euclidean distance from Kid is 0.698097
# Euclidean distance from Lucas is 0.7590382
# Euclidean distance from Joao is 1.0782471
# Euclidean distance from Kid is 0.85345614
# Euclidean distance from Lucas is 0.7549847
# Euclidean distance from Joao is 1.0333492
# Euclidean distance from Kid is 0.78070325
# Euclidean distance from Lucas is 0.7137446
# Euclidean distance from Joao is 0.89423347
# Euclidean distance from Kid is 0.8077913
# Euclidean distance from Lucas is 0.88590646
# Euclidean distance from Joao is 0.9427286
# Euclidean distance from Kid is 0.7030922
# Euclidean distance from Lucas is 0.8742614
# Euclidean distance from Joao is 0.9188565
# Euclidean distance from Kid is 0.6034484
# Euclidean distance from Lucas is 0.8875971
# Euclidean distance from Joao is 1.0154282
# Euclidean distance from Kid is 0.8260022
# Euclidean distance from Lucas is 0.72950435
# Euclidean distance from Joao is 1.006218
# Euclidean distance from Kid is 0.8280614
# Euclidean distance from Lucas is 0.71711075
# Euclidean distance from Joao is 0.8734736
# Euclidean distance from Kid is 0.5951109
# Euclidean distance from Lucas is 0.9073382
# Euclidean distance from Joao is 0.99671763
# Euclidean distance from Kid is 0.468955
# Euclidean distance from Lucas is 1.0012736
# Euclidean distance from Joao is 1.1485054
# Euclidean distance from Kid is 0.69131726
# Euclidean distance from Lucas is 0.76131105
# Euclidean distance from Joao is 0.8588642
# Euclidean distance from Kid is 0.57259566
# Euclidean distance from Lucas is 1.0861577
# Euclidean distance from Joao is 0.902765
# Euclidean distance from Kid is 0.56615424
# Euclidean distance from Lucas is 1.0283434
# Euclidean distance from Joao is 1.0398219
# Euclidean distance from Kid is 0.68022627
# Euclidean distance from Lucas is 0.9934186
# Euclidean distance from Joao is 1.0109917
# Euclidean distance from Kid is 0.5338828
# Euclidean distance from Lucas is 1.076594
# Euclidean distance from Joao is 1.0370734
# Euclidean distance from Kid is 0.59546256
# Euclidean distance from Lucas is 1.0681024
# Euclidean distance from Joao is 1.1869597
# Euclidean distance from Kid is 0.6687073
# Euclidean distance from Lucas is 1.09284
# Euclidean distance from Joao is 1.0437804
# Euclidean distance from Kid is 0.5375947
# Euclidean distance from Lucas is 1.0266243
# Euclidean distance from Joao is 0.98699486
# Euclidean distance from Kid is 0.55388767
# Euclidean distance from Lucas is 0.89699405
# Euclidean distance from Joao is 0.8617574
# Euclidean distance from Kid is 0.48676574
# Euclidean distance from Lucas is 0.87684286
# Euclidean distance from Joao is 0.8842363
# Euclidean distance from Kid is 0.45682082
# Euclidean distance from Lucas is 0.88184875
# Euclidean distance from Joao is 1.0600435
# Euclidean distance from Kid is 0.4934981
# Euclidean distance from Lucas is 1.0244228
# Euclidean distance from Joao is 0.9860487
# Euclidean distance from Kid is 0.43511572
# Euclidean distance from Lucas is 0.92125213
# Euclidean distance from Joao is 0.94242877
# Euclidean distance from Kid is 0.541583
# Euclidean distance from Lucas is 0.87671363
# Euclidean distance from Joao is 1.0230199
# Euclidean distance from Kid is 0.68694615
# Euclidean distance from Lucas is 0.85993975
# Euclidean distance from Joao is 0.93400013
# Euclidean distance from Kid is 0.44733623
# Euclidean distance from Lucas is 0.9338745
# Euclidean distance from Joao is 0.9196462
# Euclidean distance from Kid is 0.55396986
# Euclidean distance from Lucas is 0.88693887
# Euclidean distance from Joao is 0.944481
# Euclidean distance from Kid is 0.605161
# Euclidean distance from Lucas is 0.83567244
# Euclidean distance from Joao is 0.9195012
# Euclidean distance from Kid is 0.66226727
# Euclidean distance from Lucas is 0.8499406
# Euclidean distance from Joao is 1.1035472
# Euclidean distance from Kid is 0.53822684
# Euclidean distance from Lucas is 1.0436232
# Euclidean distance from Joao is 1.0211495
# Euclidean distance from Kid is 0.4921768
# Euclidean distance from Lucas is 0.9771094
# Euclidean distance from Joao is 1.0463839
# Euclidean distance from Kid is 0.5740691
# Euclidean distance from Lucas is 0.982321
# Euclidean distance from Joao is 0.9235303
# Euclidean distance from Kid is 0.4437652
# Euclidean distance from Lucas is 0.8964932
# Euclidean distance from Joao is 1.0077212
# Euclidean distance from Kid is 0.86827314
# Euclidean distance from Lucas is 0.81214106
# Euclidean distance from Joao is 1.0228827
# Euclidean distance from Kid is 0.50424826
# Euclidean distance from Lucas is 0.96419364
# Euclidean distance from Joao is 1.0578939
# Euclidean distance from Kid is 0.60434747
# Euclidean distance from Lucas is 1.023876
# Euclidean distance from Joao is 0.9511879
# Euclidean distance from Kid is 0.566932
# Euclidean distance from Lucas is 0.9517623
# Euclidean distance from Joao is 0.94489986
# Euclidean distance from Kid is 0.46011487
# Euclidean distance from Lucas is 0.91001433
# Euclidean distance from Joao is 0.9354303
# Euclidean distance from Kid is 0.44329366
# Euclidean distance from Lucas is 0.96245646
# Euclidean distance from Joao is 1.0049736
# Euclidean distance from Kid is 0.5055535
# Euclidean distance from Lucas is 0.9807956
# Euclidean distance from Joao is 0.99646294
# Euclidean distance from Kid is 0.5013143
# Euclidean distance from Lucas is 0.9758708
# Euclidean distance from Joao is 1.1005495
# Euclidean distance from Kid is 0.58316797
# Euclidean distance from Lucas is 1.0020972
# Euclidean distance from Joao is 1.0310941
# Euclidean distance from Kid is 0.5443181
# Euclidean distance from Lucas is 0.9901004
# Euclidean distance from Joao is 1.1181501
# Euclidean distance from Kid is 0.5618291
# Euclidean distance from Lucas is 1.0110508
# Euclidean distance from Joao is 0.8842568
# Euclidean distance from Kid is 0.4042303
# Euclidean distance from Lucas is 0.8475779
# Euclidean distance from Joao is 1.0452428
# Euclidean distance from Kid is 0.46057028
# Euclidean distance from Lucas is 0.985281
# Euclidean distance from Joao is 0.909704
# Euclidean distance from Kid is 0.44063732
# Euclidean distance from Lucas is 0.8731839
# Euclidean distance from Joao is 0.86323667
# Euclidean distance from Kid is 0.40420133
# Euclidean distance from Lucas is 0.9290182
# Euclidean distance from Joao is 1.0682595
# Euclidean distance from Kid is 0.5020522
# Euclidean distance from Lucas is 1.0476626
# Euclidean distance from Joao is 1.0132859
# Euclidean distance from Kid is 0.53144747
# Euclidean distance from Lucas is 1.1017513
# Euclidean distance from Joao is 0.9545794
# Euclidean distance from Kid is 0.53079313
# Euclidean distance from Lucas is 0.84865725
# Euclidean distance from Joao is 1.0551156
# Euclidean distance from Kid is 0.5674464
# Euclidean distance from Lucas is 0.9042884
# Euclidean distance from Joao is 0.8946595
# Euclidean distance from Kid is 0.53919744
# Euclidean distance from Lucas is 0.90929556

# %%
model.save("model_complete.h5")

# %%
model.save_weights('./model/model_weights.h5')

# Save the model architecture
with open('./model/model_architecture.json', 'w') as f:
    f.write(model.to_json())
